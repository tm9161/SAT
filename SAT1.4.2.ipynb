# %%
import tensorflow as tf

import cv2

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
model2 = tf.keras.models.load_model('sat75.h5')

# %%
img = cv2.imread('1.jpg',1)
#读取图片

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img = cv2.resize(img,(224,224))
img = img.reshape(1,224,224,3)
img = img/255
#图片预处理

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
predict2 = model2.predict(img)

# %%
predict2
# Out:
# [array([[9.9832672e-01, 1.4782640e-05, 5.1880648e-05, 1.6021918e-03,
#          4.4212074e-06]], dtype=float32),
#  array([[9.999976e-01, 3.903125e-08, 9.525354e-08, 2.170151e-06,
#          7.831099e-08]], dtype=float32),
#  array([[9.9998844e-01, 4.2879396e-08, 6.0872118e-08, 1.1369449e-05,
#          1.2672969e-07]], dtype=float32)]

# %%
label = ['airplane','bridge','palace','ship','stadium']
